# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine

# %%
#Extract first CSV into DataFrame
csv_file = "Datafiniti_Hotel_Reviews.csv"
datafiniti_df = pd.read_csv(csv_file)
datafiniti_df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVwc252WIN2L1WUfpqLP  2016-10-30T21:42:42Z  2018-09-10T21:06:27Z
# 1  AVwc252WIN2L1WUfpqLP  2016-10-30T21:42:42Z  2018-09-10T21:06:27Z
# 2  AVwc252WIN2L1WUfpqLP  2016-10-30T21:42:42Z  2018-09-10T21:06:27Z
# 3  AVwdOclqIN2L1WUfti38  2015-11-28T19:19:35Z  2018-09-10T21:06:16Z
# 4  AVwdOclqIN2L1WUfti38  2015-11-28T19:19:35Z  2018-09-10T21:06:16Z
#
#              address                                         categories  \
# 0  5921 Valencia Cir  Hotels,Hotels and motels,Hotel and motel reser...
# 1  5921 Valencia Cir  Hotels,Hotels and motels,Hotel and motel reser...
# 2  5921 Valencia Cir  Hotels,Hotels and motels,Hotel and motel reser...
# 3     7520 Teague Rd  Hotels,Hotels and motels,Travel agencies and b...
# 4     7520 Teague Rd  Hotels,Hotels and motels,Travel agencies and b...
#
#                primaryCategories             city country  \
# 0  Accommodation & Food Services  Rancho Santa Fe      US
# ...

# %%
#Extract second CSV into DataFrame
csv_file_two = "Datafiniti_Hotel_Reviews_Jun19.csv"
jun19_datafiniti_df = pd.read_csv(csv_file_two)
jun19_datafiniti_df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AWE2FvX5RxPSIh2RscTK  2018-01-18T18:43:12Z  2019-05-20T23:55:47Z
# 1  AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
# 2  AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
# 3  AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
# 4  AVwcj_OhkufWRAb5wi9T  2016-11-06T20:21:05Z  2019-05-20T23:31:56Z
#
#                           address  \
# 0                 5620 Calle Real
# 1  5th And San Carlos PO Box 3574
# 2  5th And San Carlos PO Box 3574
# 3  5th And San Carlos PO Box 3574
# 4  5th And San Carlos PO Box 3574
#
#                                           categories  \
# 0  Hotels,Hotels and motels,Hotel and motel mgmt....
# 1                               Hotels,Lodging,Hotel
# 2                               Hotels,Lodging,Hotel
# 3                               Hotels,Lodging,Hotel
# 4                               Hotels,Lodging,Hotel
#
# ...

# %%
# Create a filtered dataframe from specific columns
datafiniti_cols = ['id', 'name', 'address', 'latitude', 'longitude', 'postalCode', 'city', 'province', 'country', 'reviews.username', 'reviews.userCity', 'reviews.userProvince', 'reviews.date', 'reviews.rating']
datafiniti_transformed= datafiniti_df[datafiniti_cols].copy()

# Rename the column headers
datafiniti_transformed = datafiniti_transformed.rename(columns={"id": "hotel_id", "postalCode": "zipcode", "province": "state", "reviews.username": "username", "reviews.userCity": "user_city", "reviews.userProvince": "user_state", "reviews.date": "date", "reviews.rating": "rating"})

# Clean the data by dropping duplicates and setting the index
datafiniti_transformed.drop_duplicates("hotel_id", inplace=True)
datafiniti_transformed.set_index

#("id", inplace=True)

datafiniti_transformed.head()
# Out:
#                 hotel_id                                  name  \
# 0   AVwc252WIN2L1WUfpqLP            Rancho Valencia Resort Spa
# 3   AVwdOclqIN2L1WUfti38                   Aloft Arundel Mills
# 9   AVwePiAX_7pvs4fzBSAl  Hampton Inn Suites PortlandVancouver
# 15  AVwdUKE3_7pvs4fz4lE-                        Hotel Phillips
# 20  AVweQyWNkufWRAb5BZeg                    The Inn at Solvang
#
#                     address   latitude   longitude zipcode             city  \
# 0         5921 Valencia Cir  32.990959 -117.186136   92067  Rancho Santa Fe
# 3            7520 Teague Rd  39.155929  -76.716341   21076          Hanover
# 9         315 SE Olympia Dr  45.619212 -122.525196   98684        Vancouver
# 15            106 W 12th St  39.100119  -94.584701   64105      Kansas City
# 20  10611 Standing Stone Rd  40.527478  -77.969763   16652       Huntingdon
#
#    state country     username user_city user_state                  date  \
# ...

# %%
datafiniti_transformed.dtypes
# Out:
# hotel_id       object
# name           object
# address        object
# latitude      float64
# longitude     float64
# zipcode        object
# city           object
# state          object
# country        object
# username       object
# user_city      object
# user_state     object
# date           object
# rating        float64
# dtype: object

# %%
datafiniti_transformed.count
# Out:
# <bound method DataFrame.count of                   hotel_id                                               name  \
# 0     AVwc252WIN2L1WUfpqLP                         Rancho Valencia Resort Spa
# 3     AVwdOclqIN2L1WUfti38                                Aloft Arundel Mills
# 9     AVwePiAX_7pvs4fzBSAl               Hampton Inn Suites PortlandVancouver
# 15    AVwdUKE3_7pvs4fz4lE-                                     Hotel Phillips
# 20    AVweQyWNkufWRAb5BZeg                                 The Inn at Solvang
# 21    AVweQDZpIN2L1WUf3TA9                                         Econolodge
# 22    AVwdQ0dy_7pvs4fz4BqX                                        Hotel Zelos
# 26    AVwdKLPU_7pvs4fz23YA                                         EconoLodge
# 28    AWE7dKHFIxWefVJwyLgA  Hampton Inn Suites National HarborAlexandria Area
# 59    AVwcfFGw_7pvs4fzvk4S                             Fairmont Grand Del Mar
# 75    AVwdbM6R_7pvs4fz5wdc                              Best Western at OHare
# ...

# %%
# Create a filtered dataframe from specific columns
jun19_datafiniti_cols = ['id', 'name', 'address', 'latitude', 'longitude', 'postalCode', 'city', 'province', 'country', 'reviews.username', 'reviews.userCity', 'reviews.userProvince', 'reviews.date', 'reviews.rating']
jun19_datafiniti_transformed= jun19_datafiniti_df[jun19_datafiniti_cols].copy()

# Rename the column headers
jun19_datafiniti_transformed = jun19_datafiniti_transformed.rename(columns={"id": "hotel_id", "postalCode": "zipcode", "province": "state", "reviews.username": "username", "reviews.userCity": "user_city", "reviews.userProvince": "user_state", "reviews.date": "date", "reviews.rating": "rating"})

# Clean the data by dropping duplicates and setting the index
jun19_datafiniti_transformed.drop_duplicates("hotel_id", inplace=True)
jun19_datafiniti_transformed.set_index
#("hotel id", inplace=True)

jun19_datafiniti_transformed.head()
# Out:
#                hotel_id                                      name  \
# 0  AWE2FvX5RxPSIh2RscTK         Best Western Plus South Coast Inn
# 1  AVwcj_OhkufWRAb5wi9T    Best Western Carmel's Town House Lodge
# 5  AVweLARAByjofQCxv5vX                21c Museum Hotel Lexington
# 7  AV1thAoL3-Khe5l_Ott5                         Springs Motel LLC
# 8  AVz6h4Sb3D1zeR_xDHsu  Microtel Inn Suites By Wyndham Lexington
#
#                           address   latitude   longitude zipcode  \
# 0                 5620 Calle Real  34.441780 -119.819790   93117
# 1  5th And San Carlos PO Box 3574  36.557220 -121.921940   93921
# 5                   167 W Main St  38.047014  -84.497742   40507
# 7          115 W Steve Wariner Dr  37.065296  -85.073580   42642
# 8             2240 Buena Vista Rd  38.042100  -84.427100   40505
#
#                 city state country        username       user_city  \
# 0             Goleta    CA      US    tatsurok2018        San Jose
# ...

# %%
jun19_datafiniti_transformed.dtypes
# Out:
# hotel_id       object
# name           object
# address        object
# latitude      float64
# longitude     float64
# zipcode        object
# city           object
# state          object
# country        object
# username       object
# user_city      object
# user_state     object
# date           object
# rating          int64
# dtype: object

# %%
jun19_datafiniti_transformed.count
# Out:
# <bound method DataFrame.count of                   hotel_id                                               name  \
# 0     AWE2FvX5RxPSIh2RscTK                  Best Western Plus South Coast Inn
# 1     AVwcj_OhkufWRAb5wi9T             Best Western Carmel's Town House Lodge
# 5     AVweLARAByjofQCxv5vX                         21c Museum Hotel Lexington
# 7     AV1thAoL3-Khe5l_Ott5                                  Springs Motel LLC
# 8     AVz6h4Sb3D1zeR_xDHsu           Microtel Inn Suites By Wyndham Lexington
# 9     AVwdo6WHByjofQCxrGaj                                       American Inn
# 10    AVwcuo0eIN2L1WUfoPEk               Hampton Inn Lexington Medical Center
# 11    AWB2mcqARxPSIh2RpdHz          Motel 6 Santa Barbara - Carpinteria North
# 12    AVwdhvN2kufWRAb56xSm                                        Comfort Inn
# 13    AWV8VsCtRxPSIh2RyTvS                                  The Whitney Hotel
# 61    AVwd89xXkufWRAb5-sIk                                  Estes Park Condos
# ...

# %%
#Combine both cleaned dataframes and drop duplicates 
combined_transformed_df = pd.concat([datafiniti_transformed,jun19_datafiniti_transformed]).drop_duplicates()

# %%
combined_transformed_df.head()
# Out:
#                 hotel_id                                  name  \
# 0   AVwc252WIN2L1WUfpqLP            Rancho Valencia Resort Spa
# 3   AVwdOclqIN2L1WUfti38                   Aloft Arundel Mills
# 9   AVwePiAX_7pvs4fzBSAl  Hampton Inn Suites PortlandVancouver
# 15  AVwdUKE3_7pvs4fz4lE-                        Hotel Phillips
# 20  AVweQyWNkufWRAb5BZeg                    The Inn at Solvang
#
#                     address   latitude   longitude zipcode             city  \
# 0         5921 Valencia Cir  32.990959 -117.186136   92067  Rancho Santa Fe
# 3            7520 Teague Rd  39.155929  -76.716341   21076          Hanover
# 9         315 SE Olympia Dr  45.619212 -122.525196   98684        Vancouver
# 15            106 W 12th St  39.100119  -94.584701   64105      Kansas City
# 20  10611 Standing Stone Rd  40.527478  -77.969763   16652       Huntingdon
#
#    state country     username user_city user_state                  date  \
# ...

# %%
combined_transformed_df.count
# Out:
# <bound method DataFrame.count of                   hotel_id                                               name  \
# 0     AVwc252WIN2L1WUfpqLP                         Rancho Valencia Resort Spa
# 3     AVwdOclqIN2L1WUfti38                                Aloft Arundel Mills
# 9     AVwePiAX_7pvs4fzBSAl               Hampton Inn Suites PortlandVancouver
# 15    AVwdUKE3_7pvs4fz4lE-                                     Hotel Phillips
# 20    AVweQyWNkufWRAb5BZeg                                 The Inn at Solvang
# 21    AVweQDZpIN2L1WUf3TA9                                         Econolodge
# 22    AVwdQ0dy_7pvs4fz4BqX                                        Hotel Zelos
# 26    AVwdKLPU_7pvs4fz23YA                                         EconoLodge
# 28    AWE7dKHFIxWefVJwyLgA  Hampton Inn Suites National HarborAlexandria Area
# 59    AVwcfFGw_7pvs4fzvk4S                             Fairmont Grand Del Mar
# 75    AVwdbM6R_7pvs4fz5wdc                              Best Western at OHare
# ...

# %%
#Create new data with select columns
hotels_df = combined_transformed_df[['hotel_id', 'name', 'address', 'latitude', 'longitude', 'zipcode', 'city', 'state', 'country' ]].copy()
hotels_df.set_index('hotel_id', inplace=True)
hotels_df.head()
# Out:
#                                                       name  \
# hotel_id
# AVwc252WIN2L1WUfpqLP            Rancho Valencia Resort Spa
# AVwdOclqIN2L1WUfti38                   Aloft Arundel Mills
# AVwePiAX_7pvs4fzBSAl  Hampton Inn Suites PortlandVancouver
# AVwdUKE3_7pvs4fz4lE-                        Hotel Phillips
# AVweQyWNkufWRAb5BZeg                    The Inn at Solvang
#
#                                       address   latitude   longitude zipcode  \
# hotel_id
# AVwc252WIN2L1WUfpqLP        5921 Valencia Cir  32.990959 -117.186136   92067
# AVwdOclqIN2L1WUfti38           7520 Teague Rd  39.155929  -76.716341   21076
# AVwePiAX_7pvs4fzBSAl        315 SE Olympia Dr  45.619212 -122.525196   98684
# AVwdUKE3_7pvs4fz4lE-            106 W 12th St  39.100119  -94.584701   64105
# AVweQyWNkufWRAb5BZeg  10611 Standing Stone Rd  40.527478  -77.969763   16652
#
#                                  city state country
# hotel_id
# AVwc252WIN2L1WUfpqLP  Rancho Santa Fe    CA      US
# ...

# %%
#Create new data with select columns
users_df = combined_transformed_df[['username', 'user_city', 'user_state']].copy()
users_df.set_index('username', inplace=True)
users_df.head()
# Out:
#             user_city user_state
# username
# Paula             NaN        NaN
# jaeem2016    Richmond         VA
# KristyWM     Portland        NaN
# AimlessinMe       NaN        NaN
# sxk158       Istanbul        NaN

# %%
#Create new data with select columns
reviews_df = combined_transformed_df[['hotel_id', 'username', 'date', 'rating']].copy()
reviews_df.reset_index()
reviews_df.head()
# Out:
#                 hotel_id     username                  date  rating
# 0   AVwc252WIN2L1WUfpqLP        Paula  2013-11-14T00:00:00Z     5.0
# 3   AVwdOclqIN2L1WUfti38    jaeem2016  2016-05-15T00:00:00Z     2.0
# 9   AVwePiAX_7pvs4fzBSAl     KristyWM  2016-01-26T00:00:00Z     5.0
# 15  AVwdUKE3_7pvs4fz4lE-  AimlessinMe  2015-09-14T00:00:00Z     4.0
# 20  AVweQyWNkufWRAb5BZeg       sxk158  2015-05-03T00:00:00Z     5.0

# %%
#Create database connection
connection_string = "postgres:postgres@localhost:5432/Hotel_Reviews"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['hotels', 'users', 'reviews']

# %%
#Load DataFrames into database
hotels_df.to_sql(name='hotels', con=engine, if_exists='append', index=True)

# %%
users_df.to_sql(name='users', con=engine, if_exists='append', index=True)

# %%
reviews_df.to_sql(name='reviews', con=engine, if_exists='append', index=False)
